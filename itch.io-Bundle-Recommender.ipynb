# %% [markdown]
# <img src="https://static.itch.io/images/logo-black-new.svg" />

# %% [markdown]
# <center><h1> The itch.io Bundle Video Game Recommender Engine </h1></center>

# %% [markdown]
# <a href="https://itch.io/b/520/bundle-for-racial-justice-and-equality"> Bundle for Racial Justice and Equality </a> from <a href="https://itch.io/"> itch.io </a> was a huge hit. For a minimum donation of $5, those who donated gained an access to a library of 1741 digital items, including video games, game assets, soundtracks, comics, books, and much more.
#
# I was determined to address the frustration that may come with getting so many choices at once: after my donation, the amount of games was so overwhelming that I did not know where to start!
#
# I decided to build a <b>content-based recommender engine</b> that would solve this problem for me, and other gamers who own the bundle. Since many well-known websites have already made their recommendations who they thought the best games in the bundle were, I wanted to take a different approach. Lesser-known developers also deserve the chance of a mention.
#
# That is why this project relies solely on <b>Natural Language Processing (NLP)</b>, and recommends games based on their content. The content of the games is described mainly by <b>tags</b> (entered either by the developer on itch.io, or by users on steam), the <b>genre</b> of the game, and a <b>short decription</b> of the video game by the developer.
#
# The itch.io Bundle Video Game Recommender uses publicly available datasets created by users <a href="https://www.reddit.com/user/theredmist"> u/theredmist </a> and <a href="https://www.reddit.com/user/azura26"> u/azura26 </a>, and are accessible on the <a href="https://www.reddit.com/r/itchioJusticeBundle/"> itchioJusticeBundle subreddit </a>. Thanks so much for this amazing resource!

# %%
#importing the necessary libraries
import pandas as pd
import numpy as np
import re
import contractions
import nltk
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#author info
__author__ = "Lukas Barbuscak"
__email__ = "lukas.barbuscak@gmail.com"

# %%
#browsing the dataset
df = pd.read_csv("data.csv")
df.head()
# Out:
#        Title category  steam\nreviews  steam_rating\n(5 stars)  \
# 0  12 orbits     Game           197.0                      4.0
# 1    Bleed 2     Game           367.0                      4.0
# 2     COMPEL     Game             NaN                      0.0
# 3   TEOCALLI     Game             NaN                      0.0
# 4     Wondee     Game             1.0                      0.0
#
#    steamdb_score\n(5 stars)  itch.io\nratings  itch.io\nrating  \
# 0                      3.99                 1              NaN
# 1                      4.41                37              4.7
# 2                      0.00                 0              NaN
# 3                      0.00                 5              3.8
# 4                      2.97                 0              NaN
#
#    total\nratings  Net\nAvg.  Bayes\nAvg.  ...    Status   Genre  \
# 0             198      3.980        3.785  ...  Released  Action
# 1             404      4.064        3.956  ...  Released  Action
# 2               0      0.000        2.500  ...  Released  Action
# 3               5      3.800        2.686  ...  Released  Action
# 4               0      0.000        2.500  ...  Released  Action
#
#                                                 Tags   Average Time  \
# 0  10-player, 2-player, 3-player, 4-player, 5-pla...  A few minutes
# 1  16-bit, Arcade, Boss battle, Difficult, Fast-P...
# 2  1-bit, 2D, Atmospheric, Black and White, Dark,...
# 3  1-bit, 2D, Seven Day Roguelike Challenge, azte...
# 4  1d, Arcade, Colorful, Fast-Paced, gamepad, Sin...  A few minutes
#
#          Languages                                      Accessibility  \
# 0  German, English  Color-blind friendly, Configurable controls, O...
# 1
# 2
# 3
# 4          English  Color-blind friendly, Configurable controls, I...
#
#          Multiplayer Player\ncount  \
# 0  Local multiplayer      "1 - 12"
# 1
# 2
# 3
# 4
#
#                                               Inputs Unnamed: 22
# 0  Keyboard, Mouse, Xbox controller, Gamepad (any...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                            Keyboard, Gamepad (any)
#
# [5 rows x 23 columns]

# %%
#removing non-text columns
df = df[["Title", "Genre", "Tags", "Short Description"]]
df = df.sort_values("Title")
df.head(15)
# Out:
#                            Title                              Genre  \
# 340                 #hasicontent                             Casual
# 117          // Down to Earth //         Action, Adventure, Shooter
# 189  1,000 Heads Among the Trees                          Adventure
# 383  10 in 1 game-a-week bundle!                       Experimental
# 50                           10S                             Action
# 439                    12 Labors  Interactive Fiction, Visual Novel
# 0                      12 orbits                             Action
# 468                         1365                         Platformer
# 207       2000:1: A Space Felony                          Adventure
# 170     2064: Read Only Memories                          Adventure
# 850          2d flight simulator                         Simulation
# 351             4-LEGGED-HEROINE                             Casual
# 455                  8 Bit Space                         Platformer
# 962                  9 Till Void                Strategy, Card Game
# 645           A Day in the Woods                             Puzzle
#
#                                                   Tags  \
# 340     2D, 8-Bit, bunny, PICO-8, Pixel Art, wholesome
# 117  Fantasy, First-Person, Pixel Art, Retro, Singl...
# 189  3D, artgame, Experimental, First-Person, Horro...
# 383  artgame, bundle, Cute, Experimental, Funny, Ga...
# 50   Action-Adventure, Arcade, Bullet Hell, Explora...
# 439                  Interactive Fiction, Visual Novel
# 0    10-player, 2-player, 3-player, 4-player, 5-pla...
# 468  2D, artgame, Horror, memoir, mental-illness, M...
# 207  Action-Adventure, Crime, free, Mystery, Sci-fi...
# 170  2064, 2064rom, Cyberpunk, Gay, LGBT, LGBTQIA, ...
# 850              2D, airline, Flight, flight-simulator
# 351                                   Low-poly, Runner
# 455  2D, 8-Bit, Exploration, ipad, metroid, Metroid...
# 962  Deck Building, Mouse only, Pixel Art, Roguelik...
# 645  Casual, family, Female Protagonist, hexagon, s...
#
#                                      Short Description
# 340            Take fotos of the bunnys in your garden
# 117  You're a witch trying to get back to Earth aft...
# 189  Nighttime exploration of an eccentric town in ...
# 383  A bunch of games! With varying levels of good-...
# 50                                       lift the veil
# 439  A short game about working your way up to an a...
# 0    12 players, one keyboard / smartphone / gamepa...
# 468  A short, autobio platformer about mental illne...
# 207  Murder mystery courtroom drama set on an inter...
# 170                          A New Cyberpunk Adventure
# 850                      An arcade 2d flight simulator
# 351  A short-game by Sergio 'Trac' Eslava & Wolfgan...
# 455                    ZX Spectrum Inspired Platformer
# 962  Turn-based deckbuilding roguelike featuring ne...
# 645  Guide Red through the woods to help her find g...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1071 entries, 340 to 882
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1071 non-null   object
#  1   Genre              1071 non-null   object
#  2   Tags               1071 non-null   object
#  3   Short Description  1071 non-null   object
# dtypes: object(4)
# memory usage: 41.8+ KB

# %%
#combining the text features into one
df["description"] = df["Title"] + " " + df["Genre"] + " " + df["Tags"] + " " + df["Short Description"]

#creating a series and a list with only video game titles
games_titles = df["Title"].values
games_list=games_titles.tolist()

# %%
#stemming
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
df['description'] = df['description'].apply(porter.stem)

#defining stopwords
stopwords = nltk.corpus.stopwords.words('english')

# %%
#defining a function that normalizes text features
def normalize(text):
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text, re.I|re.A)
    text = text.lower()
    text = contractions.fix(text)
    tokens = nltk.word_tokenize(text)
    filtered = [token for token in tokens if token not in stopwords]
    text = " ".join(filtered)
    return text

# %%
#creating the normalized text
vectorized = np.vectorize(normalize)
normalized = vectorized(list(df['description']))
print(normalized)
# Out:
# ['hasicontent casual 2d 8bit bunny pico8 pixel art wholesome take fotos bunnys garden'
#  'earth action adventure shooter fantasy firstperson pixel art retro singleplayer solodev soundtrack vaporwave witch trying get back earth crash landing mysterious planet space cats pleased'
#  '1000 heads among trees adventure 3d artgame experimental firstperson horror photography travel nighttime exploration eccentric town peruvian desert'
#  ...
#  'used someone simulation dark humor depression firstperson queer walking simulator weird solitary walk night'
#  'escape kabagahara interactive fiction adventure survival ascii experimental exploration horror retro survival horror text based unity see path kabagahara take'
#  'bonsai calendar simulation bonsai colorful coop dating sim exploration minimalist perma death surreal weird piece software helps one take good care hisher bonsai tree']

# %%
#applying TF-IDF
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(normalized)

#computing cosine similarities
cosine_similarities = cosine_similarity(tfidf)
similarities_df = pd.DataFrame(cosine_similarities)

# %%
#defining the recommender function
def recommender(game, games=games_titles, similarity_score=similarities_df):
    game_id = np.where(games == game)[0][0]
    game_similarities = similarity_score.iloc[game_id].values
    similar_game_ids = np.argsort(-game_similarities)[1:6]
    similar_games = games[similar_game_ids]
    return similar_games

# %%
#printing the recommendations for each game
for game in games_list:
    print('Game Title:', game)
    print('Recommended:', recommender(game, games=games_titles, similarity_score=similarities_df))
    print()
# Out:
# Game Title: #hasicontent
# Recommended: ['Best Garden' 'Galactic Wars' 'ZEPTON' 'Blaster Bunny +'
#  'Pixel Session Vol.1']
#
# Game Title: // Down to Earth //
# Recommended: ['Astral Defense' 'The Aquatic Adventure of the Last Human' 'Witch Thief'
#  'Space Duet™' 'They Come From Uranus!']
#
# Game Title: 1,000 Heads Among the Trees
# Recommended: ['Astæria' 'Fugue in Void' 'Quiet as a Stone'
#  'Wakamarina Valley, New Zealand' 'Shutter Stroll']
#
# Game Title: 10 in 1 game-a-week bundle!
# Recommended: ['Winter Bundle (ENG)' 'Atchafalaya Arcade' 'The Night Journey' 'Astæria'
#  'Jupitron Game Collection Vol.1']
#
# Game Title: 10S
# Recommended: ['The Last Librarian' 'Jet Buster' 'Lacrymo Tennis 2016 (+ 2018)'
#  'Ryza Roads' 'Myth Bearer']
#
# Game Title: 12 Labors
# Recommended: ['Bunny Hill Horror' 'Serre' 'The Night Fisherman' 'Arcade Spirits'
#  'a new life.']
#
# Game Title: 12 orbits
# Recommended: ['BFF or Die' 'Oh No! Bugs!' 'KeyCars' 'Turn-Based Champion' 'SHNIPERS']
#
# Game Title: 1365
# Recommended: ['Midnight Manor' 'please' 'Please Follow' 'Self.destroy()' 'down.']
#
# Game Title: 2000:1: A Space Felony
# Recommended: ['Broken Minds' 'Eye of Ra' 'J.U.L.I.A.: Among the Stars'
#  'The Space Between' 'The Fall of Lazarus']
#
# Game Title: 2064: Read Only Memories
# Recommended: ['nullpointer' 'Quadrilateral Cowboy' 'INDECT' 'Newfound Courage' 'Homing']
#
# Game Title: 2d flight simulator
# Recommended: ['A e r o c r a f t' 'Scrapper' 'Nest Lander' 'Barrel Roll' 'Cat Ace']
#
# Game Title: 4-LEGGED-HEROINE
# Recommended: ['Void Runner' 'NO THING' 'Shadowcut' 'Super Sellout' 'Cotrio']
#
# Game Title: 8 Bit Space
# Recommended: ['The Curse of Trasmoz' "Jumpin' Jupiter : Prelude" 'Corey Coolbrew'
#  'Cecconoid' 'Tiny Dangerous Dungeons']
#
# Game Title: 9 Till Void
# Recommended: ['The Land of Glass' 'Glitch Strike' 'Deck Defenders [Demo Available!]'
#  'Feud' 'Depth of Extinction']
#
# Game Title: A Day in the Woods
# Recommended: ['Night in the Woods' 'The Novelist' 'Wild Woods' 'Walden, a game'
#  'The House on Holland Hill']
#
# Game Title: A Game of Changes
# Recommended: ['tumbleblox' 'ART SQOOL' 'That Puzzle Game Everyone Knows'
#  'Golden Treasure: The Great Green' 'OneShot']
#
# Game Title: A Hole New World
# Recommended: ['Drive to Hell' 'DROPSHIP' 'Rex: Another Island' 'On Rusty Trails'
#  'They Come From Uranus!']
#
# Game Title: A Kishoutenketsu in the countryside
# Recommended: ['Quiet as a Stone' 'Wakamarina Valley, New Zealand'
#  'Adventures of a Radish(Full)' 'Campfire Cooking' 'HubWorld']
#
# Game Title: A Light Long Gone
# Recommended: ['Rooftop Cop' 'VIRTUA BLINDS' 'Soundodger+' 'Refactor' 'Thing-in-Itself']
#
# Game Title: A Lullaby of Colors (now available for Oculus Quest too)
# Recommended: ['soundStrider' 'Rulent Tower VR' 'GNOG'
#  'Antigas Constelações (sobre a Vila Itororó)' 'These Lands']
#
# Game Title: A Magical Tale: Cavern Crawler
# Recommended: ['Hammer Bomb' 'SilverQuest Gaiden' 'ARGH-P-G' 'Knights of the Card Table'
#  'VIDEGOAME']
#
# Game Title: A Mortician's Tale
# Recommended: ['The Müll Littoral' 'Pendula Swing: The Complete Journey'
#  'Brassica - A Marry Tale' 'Retrace' 'Belong']
#
# Game Title: A NIGHTMARE'S TRIP
# Recommended: ['Highway Blossoms: Remastered' 'warm' 'Talk To Me'
#  'One-Eyed Lee: Prologue' 'Serre']
#
# Game Title: A Normal Lost Phone
# Recommended: ["Another Lost Phone: Laura's Story" 'ring ring'
#  'a completely normal dating simulation that is definitely completely sweet, innocent and normal'
#  'The Fall of Lazarus' 'Broken Minds']
#
# Game Title: A Short Hike
# Recommended: ['Shutter Stroll' 'The World Begins With You' 'Guide of the Butterfly'
#  'Kingdom Ka' "Marie's Room"]
#
# Game Title: A Snake's Tale
# Recommended: ['Snake Blocks' 'adjacency' 'Puzzle Puppers' 'Heavy Bullets'
#  'Brassica - A Marry Tale']
#
# Game Title: A Wish Upon A Star
# Recommended: ['Puzzle Puppers' "Death's Life" 'IGEO' 'Inner' 'Atomic Reconstruction']
#
# Game Title: A e r o c r a f t
# Recommended: ['2d flight simulator' 'Scrapper' 'Nest Lander' 'TAMASHII' 'Antistatic']
#
# Game Title: ACIDTRIP
# Recommended: ['NeoLite' 'Soldier of Fortune' 'Hyper Sentinel' 'Zenodyne R'
#  'Super Ledgehop: Double Laser']
#
# Game Title: ADLENGINE - Roleplay / Text Adventure Engine
# Recommended: ['[SIBERIA]' 'The Away Team' 'if not us' 'Tales from the Road'
#  'Your Future Self']
#
# Game Title: AIdol
# Recommended: ['Prince of Cats' 'Blue Rose' 'As We Know It' '12 Labors'
#  'Highway Blossoms: Remastered']
#
# Game Title: ALL-STARS DUNGEONS AND DIAMONDS
# Recommended: ['Blockara' 'Crate Punks' 'Tiny Dangerous Dungeons' 'SHNIPERS' 'Metori']
#
# Game Title: ARGH-P-G
# Recommended: ['Sverdheim' 'Paranautical Activity' 'Emberlight' 'Hammer Bomb'
#  'Possession']
#
# Game Title: ART SQOOL
# Recommended: ['Synestia' 'TorqueL / トルクル' 'ISLANDS: Non-Places' 'Cell Tune'
#  'Brave Hero Yuusha EX']
#
# Game Title: Abomination Tower
# Recommended: ['Stick Nightmare' 'Nine Nines' 'Gumgem' 'Perspectrum' 'Fossil Echo']
#
# Game Title: Above: The Fallen
# Recommended: ["Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-" 'Escape from Life Inc'
#  'Nótt & Dagr' 'Brathian' 'Perspectrum']
#
# Game Title: Adventures of a Radish(Full)
# Recommended: ['The Adventures of Elena Temple: Definitive Edition' 'WitchWay'
#  'Pixel Session Vol.1' 'Drake' 'EAT GIRL']
#
# Game Title: Aerannis
# Recommended: ['Vision Soft Reset' 'Neon Blight: Final Demo' 'Mable & The Wood'
#  'Quadrilateral Cowboy' 'Cuckoo Castle']
#
# Game Title: Affinity
# Recommended: ['Theorem' 'adjacency' 'Cardinal Chains' 'Dis Pontibus' 'Cotrio']
#
# Game Title: Airships: Conquer the Skies
# Recommended: ['Steam Marines 2' 'Steam Marines' 'RogueCraft Squadron' 'Gataela'
#  'Annwn: the Otherworld']
#
# Game Title: Akurra (Demo)
# Recommended: ['Block Out' 'Ghost Story' 'IGEO' 'Patches Of Adventure' 'Shipwreck']
#
# Game Title: Akuto: Showdown
# Recommended: ['Peck N Run' 'Hyperspace Dogfights' 'Timebomb' 'Clash of Coins'
#  'Over Run']
#
# Game Title: Alfal's Grove
# Recommended: ['BEACON' 'Gutwhale' 'nullpointer' 'Gun Rounds' 'Paranautical Activity']
#
# Game Title: Alien Life Lab
# Recommended: ['Stellaxy' 'Graveyard Shift' 'Grime & Gaslight'
#  'Into The Mist 2: The Cult' 'NIGHT OF THE CONSUMERS']
#
# Game Title: All Haze Eve
# Recommended: ['Halloween Forever' 'Spooky Ghosts Dot Com' 'Graveyard Shift'
#  'Please Follow' 'Spooky Station']
#
# Game Title: All You Can Eat
# Recommended: ["Old Man's Journey" 'The Old Man + Extra chapter'
#  'Eselmir and the five magical gifts' 'Clam Man' 'Without Escape']
#
# Game Title: An Airport Game
# Recommended: ['2d flight simulator' 'OneShot' 'Crystal Story: Awakening' 'Shipwreck'
#  'Danger Crew']
#
# Game Title: An American Werewolf in LA (EN)
# Recommended: ['Chipmonk!' 'Speed Farmers' 'Crate Punks' 'GourMelee' 'Hooklings']
#
# Game Title: Anarcute
# Recommended: ['Tonight We Riot' 'Christmas Cats Revenge' 'Lazy Galaxy: Rebel Story'
#  'Dragondot 3' 'The Sword and the Slime']
#
# Game Title: And All Would Cry Beware!
# Recommended: ['Penance' 'Portal Dogs' 'Hero Generations' 'Aerannis' 'SYSCRUSHER']
#
# Game Title: And Yet It Moves
# Recommended: ['Rex: Another Island' 'Gambol' 'Turn Chase' 'Butterflies - Episode 1'
#  'Dis Pontibus']
#
# Game Title: Animal Lover
# Recommended: ['songs and flowers' 'Belong' 'Prince of Cats'
#  'Who Killed My Father Academy!' 'Meeting in the Flesh']
#
# Game Title: Annwn: the Otherworld
# Recommended: ['RogueCraft Squadron' 'Feud' 'Empyrean Frontier' 'Interstellaria'
#  'Not the Robots']
#
# Game Title: Anodyne
# Recommended: ['The Last Librarian' 'Shipwreck'
#  'The Aquatic Adventure of the Last Human' 'Jabberwocky' "Giant's Chalice"]
#
# Game Title: Anomalies
# Recommended: ['Sverdheim' 'adjacency' 'Miles Infernum' 'HexaCycle' 'Shutter Stroll']
#
# Game Title: Another Lost Phone: Laura's Story
# Recommended: ['A Normal Lost Phone' 'ring ring' 'Sagebrush' 'Thing-in-Itself'
#  'Forever Lost: Episode 2']
#
# Game Title: Antigas Constelações (sobre a Vila Itororó)
# Recommended: ['A Lullaby of Colors (now available for Oculus Quest too)'
#  'Rulent Tower VR' 'These Lands' 'Crashed Lander' 'Perpetuum Mobile']
#
# Game Title: Antistatic
# Recommended: ['Bomsy' 'Crate Punks' 'FLAT FORM FIGHTER' 'SHNIPERS'
#  'Turn-Based Champion']
#
# Game Title: Arcade Spirits
# Recommended: ['songs and flowers' 'a new life.' 'Meeting in the Flesh' 'Roll+Heart'
#  'Love Hues! [Full Game]']
#
# Game Title: Arigatou, Ningen-san!
# Recommended: ['Prince of Cats' '12 Labors' 'Hidden Paws' 'Quench' 'a new life.']
#
# Game Title: Arlo The Rabbit
# Recommended: ['Parsnip' 'Blitz Breaker' 'Tiny Dangerous Dungeons' 'Lonely Wolf Treat'
#  'Fossil Echo']
#
# Game Title: As We Know It
# Recommended: ['Blue Rose' 'Prince of Cats' 'warm' 'Serre' 'Overland']
#
# Game Title: Asteroid Farmer
# Recommended: ['Asteroid Quest! (Classic)' 'Perpetuum Mobile' 'Falling Skies'
#  'Rogue Rocks' 'Kaiju Big Battel: Fighto Fantasy']
#
# Game Title: Asteroid Quest! (Classic)
# Recommended: ['Asteroid Farmer' 'Cycle 28' 'Deeper Into Space' 'Rogue Rocks'
#  'Falling Skies']
#
# Game Title: Astral Defense
# Recommended: ['Deeper Into Space' 'Hyper Sentinel' 'Sonar Smash' 'Stellaxy'
#  'Zenodyne R']
#
# Game Title: Astrologaster
# Recommended: ['Arcade Spirits' 'MetaWare High School (Demo)' 'HEADLINER'
#  'Moonstone Deep' 'Sorbetta: Gravely in Debt']
#
# Game Title: Astæria
# Recommended: ['Fugue in Void' 'The Night Journey' 'Hotel Paradise' 'PHN-HOME'
#  'Atchafalaya Arcade']
#
# Game Title: Atchafalaya Arcade
# Recommended: ['The Night Journey' 'Astæria' 'SOMOS' 'adjacency' 'Fugue in Void']
#
# Game Title: Atomic Heist
# Recommended: ['Deeper Into Space' 'Cycle 28' 'Hyper Sentinel' 'SuperLuminauts'
#  'Resistance is Fruitile']
#
# Game Title: Atomic Reconstruction
# Recommended: ['Atomic Heist' 'No More Kings' 'A Wish Upon A Star'
#  'That Puzzle Game Everyone Knows' 'Puzzle Puppers']
#
# Game Title: Attrition: Tactical Fronts
# Recommended: ['Feud' "Lew Pulsipher's Doomstar" 'Glitch Strike' 'Turn Chase'
#  '9 Till Void']
#
# Game Title: Autumn
# Recommended: ['Ungrounded' 'Codemancer' 'Spring Falls' 'plant daddy' 'The Deer God']
#
# Game Title: B.O.O.M. - You Win [Early Access]
# Recommended: ['Boom Boom Bovine' 'Turn-Based Champion' 'Served' 'Super Dunkman'
#  'Pin Puck']
#
# Game Title: BADBLOOD
# Recommended: ['Monster Jaunt' 'Turn-Based Champion' 'DANGEROUS DUELS'
#  'EleMetals: Death Metal Death Match' 'Pin Puck']
#
# Game Title: BAKED:MAGIC
# Recommended: ['By Your Side' 'Serre' 'Blue Rose' 'Highway Blossoms: Remastered'
#  'songs and flowers']
#
# Game Title: BALL BUSTER
# Recommended: ["Switch 'N' Shoot" 'Stophat' 'Pixel Session Vol.1' 'Timebomb'
#  'Space Duet™']
#
# Game Title: BEACON
# Recommended: ['Resistance is Fruitile' 'Atomic Heist' 'Rogue Rocks' 'Plunge'
#  "Alfal's Grove"]
#
# Game Title: BFF or Die
# Recommended: ['Wild Woods' 'Joggernauts' 'Crate Punks' 'Hooklings' 'Fossil Hunters']
#
# Game Title: BIT RAT : Singularity
# Recommended: ['Quadrilateral Cowboy' 'nullpointer' 'INDECT' 'Neon Blight: Final Demo'
#  '2064: Read Only Memories']
#
# Game Title: BOTOLO
# Recommended: ['Bomsy' 'Antistatic' 'SHNIPERS' 'Crate Punks' 'Color Cannons+']
#
# Game Title: BREAKER
# Recommended: ['They Come From Uranus!' 'Ghost Grab 3000' 'Astral Defense'
#  'Space Mayhem' 'Infiniboss']
#
# Game Title: BRKÖUT
# Recommended: ['Vegetables Deluxe C64' 'BREAKER' 'The Secret of Tremendous Corporation'
#  "Hunter's Moon Remastered" 'Stoneblade']
#
# Game Title: BROKEN SIGNAL
# Recommended: ['Paranautical Activity' 'SYSCRUSHER' 'Nine Nines' 'Graveyard Shift'
#  'nullpointer']
#
# Game Title: Babysitter Bloodbath
# Recommended: ['Grime & Gaslight' 'Inner' 'IMMURE' 'NIGHT OF THE CONSUMERS'
#  'String Tyrant']
#
# Game Title: Back To Bed
# Recommended: ['Inner' 'IMMURE' 'Grime & Gaslight' 'NIGHT OF THE CONSUMERS'
#  'String Tyrant']
#
# Game Title: BackFire
# Recommended: ['No cortarás a tu hermana con el filo de esta espada' 'Penance'
#  'Forgiveness : Escape Room' 'El Tango de la Muerte' 'Nano Driller']
#
# Game Title: Backspace Bouken
# Recommended: ['Hammer Bomb' 'SilverQuest Gaiden' 'Dungeon Nightmares II - The Memory'
#  'ARGH-P-G' 'Emberlight']
#
# Game Title: Bad Government
# Recommended: ['The Dastardly Dairy Debacle' 'Democratic Socialism Simulator'
#  'Radical Solitaire' 'Dujanah' 'Depth of Extinction']
#
# Game Title: Barrel Roll
# Recommended: ['2d flight simulator' 'A e r o c r a f t' 'TorqueL / トルクル'
#  'The Alabaster Donut Farm' 'Location Withheld Demake']
#
# Game Title: BasketBelle
# Recommended: ['Super Dunkman' 'LaserCat' 'Served' 'Discsphere' 'Watch Me Jump']
#
# Game Title: Bazookrash
# Recommended: ['EVADER' 'Penance' 'Retromancer' 'Bonbon' 'Alien Life Lab']
#
# Game Title: Bear-ly There
# Recommended: ['Cell Tune' 'Bazookrash' 'Hot Pot Panic' 'Karambola' 'Village Monsters']
#
# Game Title: Beglitched
# Recommended: ['Quadrilateral Cowboy' 'Soldier of Fortune' 'Eves Drop' 'NeoLite'
#  'Plana Gravatatis']
#
# Game Title: Behind the Masc
# Recommended: ['Boa Retina' 'Homing' 'Touhou Fan Game Jam Black Lives Matter Collection'
#  'Dominique Pamplemousse in "It\'s All Over Once The Fat Lady Sings!"'
#  'Talk To Me']
#
# Game Title: Belong
# Recommended: ['Blue Rose' 'songs and flowers' 'Destiny Fails Us: A New Life'
#  'Changeling' 'This World Unknown']
#
# Game Title: Benjamin of Blackstone Edge
# Recommended: ['Moonstone Deep' 'Book of Eos' 'Image of Perfection' 'VoltAge:Genesis'
#  'Four Horsemen']
#
# Game Title: Best Garden
# Recommended: ['#hasicontent' 'Garden Match' 'Desktop Meadow' 'RISK SYSTEM'
#  'Whipped And Steamy • Cosplay Café']
#
# Game Title: Bestiary
# Recommended: ['Synestia' 'ART SQOOL' 'Shutter Stroll' 'ViCam' '2d flight simulator']
#
# Game Title: Better to Upload Two Souls
# Recommended: ['IMMURE' 'Speed Farmers' 'Project Kat' 'Grime & Gaslight'
#  'MORTAGH: COLLECTOR of SOULS']
#
# Game Title: Bewildebots
# Recommended: ['Mastermind Classic' 'Infiniboss' 'Not the Robots' 'Alien Life Lab'
#  'Cardinal Chains']
#
# Game Title: Binaries
# Recommended: ['Stick Nightmare' 'Color Jumper' 'Perspectrum' 'LOVE' 'adjacency']
#
# Game Title: Binary Heresy
# Recommended: ['Resistance is Fruitile' 'ACIDTRIP' 'Infiniboss' 'Discsphere'
#  'Blast Rush']
#
# Game Title: Bitcoin Miner: Remastered
# Recommended: ['Synestia' 'Space Mining Clicker' 'Extreme Mining'
#  "Hunter's Moon Remastered" 'They Come From Uranus!']
#
# Game Title: Blast Rush
# Recommended: ['Cycle 28' 'Super Ledgehop: Double Laser' 'Those Spacecrafts'
#  'Jet Buster' 'Zenodyne R']
#
# Game Title: Blaster Bunny +
# Recommended: ['Roguescape' 'Sverdheim' 'Deeper Into Space' 'Destructivator 2'
#  'OMEGANAUT']
#
# Game Title: Blasting Agent: Ultimate Edition
# Recommended: ['Blitz Breaker' 'The Adventures of Elena Temple: Definitive Edition'
#  'Underhero' 'Perspectrum' 'Zak']
#
# Game Title: Bleed
# Recommended: ['Bleed 2' 'Resistance is Fruitile' 'There Will Be Ink' 'Cycle 28'
#  'SuperLuminauts']
#
# Game Title: Bleed 2
# Recommended: ['Bleed' "Switch 'N' Shoot" 'Astral Defense' 'They Bleed Pixels'
#  'Sonar Smash']
#
# Game Title: Blind Men
# Recommended: ['Inverness Nights' 'Serre' 'Blue Rose' 'a new life.' 'Arcade Spirits']
#
# Game Title: Blitz Breaker
# Recommended: ['Perspectrum' 'WILOO' 'Silver Grapple' 'iZBOT'
#  'Blasting Agent: Ultimate Edition']
#
# Game Title: Block Out
# Recommended: ['Cat Ace' 'Super Ledgehop: Double Laser' 'Cycle 28' 'Jet Buster'
#  'SuperLuminauts']
#
# Game Title: Blockara
# Recommended: ['WaveCrash!!' 'Crate Punks' 'SHNIPERS' 'Bomsy' "The Wolf's Bite"]
#
# Game Title: Blood Bullets & Ballet
# Recommended: ['No cortarás a tu hermana con el filo de esta espada'
#  'El Tango de la Muerte' 'Heavy Bullets' 'An American Werewolf in LA (EN)'
#  'Un Pas Fragile']
#
# Game Title: BloodBlast VR
# Recommended: ['OMEGANAUT' 'These Lands' 'Perpetuum Mobile' 'VekWars'
#  'Cabbibos Play Pack']
#
# Game Title: Blue Rose
# Recommended: ['As We Know It' 'This World Unknown' 'songs and flowers' 'Belong'
#  'BAKED:MAGIC']
#
# Game Title: Boa Retina
# Recommended: ['Atchafalaya Arcade' 'Fugue in Void' 'Behind the Masc'
#  'Dominique Pamplemousse in "It\'s All Over Once The Fat Lady Sings!"'
#  'The Space Between']
#
# Game Title: Bold Blade
# Recommended: ['The Sword and the Slime' 'Jabberwocky' 'ARGH-P-G' 'Swung' 'Dragondot 3']
#
# Game Title: Bomb Dolls
# Recommended: ['DriftKing 2D' 'Overland' 'Astral Defense' 'Keep It Together'
#  'Sonar Smash']
#
# Game Title: Bomsy
# Recommended: ['Antistatic' 'Clash of Coins' 'SHNIPERS' 'Blockara' 'Turn-Based Champion']
#
# Game Title: Bonbon
# Recommended: ['Sagebrush' 'please' 'Please Follow' 'IMMURE' 'The Fall of Lazarus']
#
# Game Title: Book of Eos
# Recommended: ['Benjamin of Blackstone Edge' 'Moonstone Deep' 'Tales Across Time'
#  'Legend of Hand' 'VoltAge:Genesis']
#
# Game Title: Boom Boom Bovine
# Recommended: ['B.O.O.M. - You Win [Early Access]' 'Splodey Vaders' 'Toaster Jam'
#  'Peck N Run' 'Speed Farmers']
#
# Game Title: BoomTown
# Recommended: ['Stoneblade' 'Erth' 'Stophat' 'Mendel' 'SPACEBEEF']
#
# Game Title: Borb the Birb
# Recommended: ['Shutter Stroll' 'IGEO' 'Secrets of Raetikon' 'Polymute' 'Hotel Paradise']
#
# Game Title: Boreal Tenebrae
# Recommended: ['Manna for our Malices' 'IMMURE' 'Bonbon' 'Stars Die' 'Hedera']
#
# Game Title: Brassica - A Marry Tale
# Recommended: ['Prince of Cats' 'The Three-Body Problem' 'Luna' 'songs and flowers'
#  'Book of Eos']
#
# Game Title: Brathian
# Recommended: ['Hooklings' 'Nótt & Dagr' 'BFF or Die' 'Crate Punks'
#  'Escape from Life Inc']
#
# Game Title: Brave Hero Yuusha EX
# Recommended: ['Danger Zone Friends' 'Ominous!' 'Soma Spirits: Rebalance'
#  'I Have Low Stats But My Class Is "Leader", So I Recruited Everyone I Know To Fight The Dark Lord'
#  'Epic Battle Fantasy 4']
#
# Game Title: Brendan Keogh's Putting Challenge
# Recommended: ['Golf Peaks' 'ZEPTON' 'Walking Tourist' 'Watch Me Jump' 'BasketBelle']
#
# Game Title: Brick Breaker Remix
# Recommended: ['Throw Cubes into Brick Towers To Collapse Them' 'BREAKER'
#  'Blitz Breaker' 'Xander the Monster Morpher: Universe Breaker'
#  'BALL BUSTER']
#
# Game Title: Broken Minds
# Recommended: ['Dry Drowning' 'Towayami' 'Retrace' '2000:1: A Space Felony'
#  'This Strange Realm Of Mine']
#
# Game Title: Brushwood Buddies
# Recommended: ['Erth' 'Oh Jeez, Oh No, My Rabbits Are Gone!!!'
#  'That Puzzle Game Everyone Knows' 'Ollie & Bollie: Outdoor Estate'
#  'The Real Texas']
#
# Game Title: Bubbles the Cat
# Recommended: ['WILOO' 'Cats are Liquid - A Better Place'
#  "Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-" "Switch 'N' Shoot"
#  'Cats are Liquid - A Light in the Shadows']
#
# Game Title: BulletHell Planes
# Recommended: ['Cat Ace' 'Hyper Sentinel' 'Task Force Kampas' "Switch 'N' Shoot"
#  'Those Spacecrafts']
#
# Game Title: Bumper Boss
# Recommended: ['Turn-Based Champion' 'SuperLuminauts' 'Wild Woods' 'Bomsy' 'Antistatic']
#
# Game Title: Bunny Hill Horror
# Recommended: ['please' '12 Labors' 'Please Follow' 'IMMURE' 'The Whisperer in Darkness']
#
# Game Title: Butsbal
# Recommended: ['DANGEROUS DUELS' 'Shoot Shoot Mega Pack' 'Dual Pong' 'Meditation 5'
#  'SuperLuminauts']
#
# Game Title: Butterflies - Episode 1
# Recommended: ['Fumiko!' 'Ryza Roads' 'Magic Trick' 'Rex: Another Island'
#  'Celestial Hacker Girl Jessica']
#
# Game Title: By Your Side
# Recommended: ['BAKED:MAGIC' 'Serre' 'Highway Blossoms: Remastered' 'Make It Last'
#  'Prince of Cats']
#
# Game Title: C.M.Y.K
# Recommended: ['GourMelee' 'Shoot Shoot Mega Pack' 'SuperLuminauts' 'Toto Temple Deluxe'
#  'Turn-Based Champion']
#
# Game Title: CARBAGE
# Recommended: ['Daemon Detective Racing Zero' 'Turn-Based Champion' 'GourMelee'
#  'Toto Temple Deluxe' 'Blockara']
#
# Game Title: CHESTO - At the Checkout
# Recommended: ['ZEPTON' 'please' 'Please Follow' 'Oh No! Bugs!'
#  'The Indifferent Wonder of an Edible Place']
#
# Game Title: CLOSER TIES - Game Pack
# Recommended: ['Online Simulator' 'Cabbibos Play Pack' 'Shoot Shoot Mega Pack'
#  'Spooky Station' 'Cell Tune']
#
# Game Title: COMPEL
# Recommended: ['Luminous' 'Daydreamour'
#  'The Adventures of Elena Temple: Definitive Edition' 'EAT GIRL'
#  'Block Out']
#
# Game Title: CORPSE REVIVER
# Recommended: ['Super Ledgehop: Double Laser' 'Jet Buster' 'Zone of Lacryma'
#  'Crystal Control II' 'JUMPGRID']
#
# Game Title: Cabbibos Play Pack
# Recommended: ['These Lands' 'BloodBlast VR' 'VekWars' 'Sushi Master VR -  寿司職人VR -'
#  '[HTC Vive] VR Drum Studio']
#
# Game Title: Campfire Cooking
# Recommended: ['Served' 'Flash Point: Fire Rescue' 'A Short Hike' 'Pixel Fireplace'
#  'Affinity']
#
# Game Title: Can Androids Pray: Red
# Recommended: ['EXTREME MEATPUNKS FOREVER' 'Last Word' '12 Labors' 'Bunny Hill Horror'
#  'Tales From Windy Meadow']
#
# Game Title: Cannon Father
# Recommended: ['Captain MaCaw' 'The Novelist' '[SIBERIA]'
#  'Who Killed My Father Academy!' 'Skeletris']
#
# Game Title: Captain MaCaw
# Recommended: ['Drake' 'Cannon Father' 'TAMASHII' 'Blaster Bunny +' 'Circa Infinity']
#
# Game Title: Cardiac
# Recommended: ['IMMURE' 'please' 'Please Follow' 'Bunny Hill Horror' 'Halloween Forever']
#
# Game Title: Cardinal Chains
# Recommended: ['adjacency' 'Dawn of a Soul' 'Affinity' 'Flufftopia' 'Theorem']
#
# Game Title: Cascadio
# Recommended: ['Sheepless Nights (Math cardgame)' 'PHN-HOME' 'Fugue' 'HexaCycle'
#  'No More Kings']
#
# Game Title: Cat Ace
# Recommended: ['Cycle 28' 'Block Out' 'Super Ledgehop: Double Laser' 'Hyper Sentinel'
#  'Over Run']
#
# Game Title: Catacombs 1: Demon War
# Recommended: ['Honor Cry: Aftermath' 'Possession' 'Emberlight' 'MidBoss'
#  'Depth of Extinction']
#
# Game Title: Catlandia: Crisis at Fort Pawprint
# Recommended: ['Cats are Liquid - A Better Place' 'Ephemeral Tale'
#  'Cats are Liquid - A Light in the Shadows' 'Thou Shalt Be Brave'
#  'Danger Crew']
#
# Game Title: Catlateral Damage
# Recommended: ['nullpointer' 'Pet the Pup at the Party'
#  'Cats are Liquid - A Better Place'
#  'Cats are Liquid - A Light in the Shadows' 'The House on Holland Hill']
#
# Game Title: Cats are Liquid - A Better Place
# Recommended: ['Cats are Liquid - A Light in the Shadows'
#  "Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-" 'Bubbles the Cat'
#  'Catlandia: Crisis at Fort Pawprint' 'Spooky Ghosts Dot Com']
#
# Game Title: Cats are Liquid - A Light in the Shadows
# Recommended: ['Cats are Liquid - A Better Place'
#  "Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-" 'Bubbles the Cat'
#  'Catlandia: Crisis at Fort Pawprint' 'Color Jumper']
#
# Game Title: Cecconoid
# Recommended: ['The Curse of Trasmoz' '8 Bit Space' "Jumpin' Jupiter : Prelude"
#  'Resistance is Fruitile' 'Corey Coolbrew']
#
# Game Title: Celeste
# Recommended: ['A Short Hike' 'Fossil Echo' 'Orbis - Throw them all!' 'Cosmonaut'
#  'Honor Cry: Aftermath']
#
# Game Title: Celestial Correspondence
# Recommended: ['U.F.O - Unfortunately Fortunate Organisms' 'Neon Blight: Final Demo'
#  'Hive Time' 'Odd Realm' 'Intelligent Design: An Evolutionary Sandbox']
#
# Game Title: Celestial Hacker Girl Jessica
# Recommended: ['Us Lovely Corpses' 'Little Bug (full version)' 'Fumiko!'
#  'Butterflies - Episode 1' 'EAT GIRL']
#
# Game Title: Cell Tune
# Recommended: ['Intelligent Design: An Evolutionary Sandbox' 'Vilmonic'
#  'Village Monsters' 'Mon-cuties for All' 'Isolation Story']
#
# Game Title: Central Limit Theorem
# Recommended: ['Cat Ace' 'They Come From Uranus!' 'Over Run' 'Meditation 5'
#  'Those Spacecrafts']
#
# Game Title: Changeling
# Recommended: ['Blue Rose' 'songs and flowers' 'Belong' 'Arcade Spirits'
#  'That Which Binds Us']
#
# Game Title: Chess Mix
# Recommended: ['No More Kings' 'ECON - Elemental Connection' 'NEXT JUMP: Shmup Tactics'
#  'Mastermind Classic' 'Depth of Extinction']
#
# Game Title: Chimpology
# Recommended: ['Zenodyne R' 'Astral Defense' 'WretchWorks Arcade Pack'
#  'Secret Little Haven' 'Zenohell']
#
# Game Title: Chipmonk!
# Recommended: ['An American Werewolf in LA (EN)' 'Tonight We Riot' 'Speed Farmers'
#  'Crate Punks' 'Turn-Based Champion']
#
# Game Title: Choice Chamber
# Recommended: ['Rogues Like Us' 'HexaCycle' 'Gumgem' 'Stellaxy' "Lenna's Inception"]
#
# Game Title: Chook & Sosig: Walk the Plank
# Recommended: ['Jam and the Mystery of the Mysteriously Spooky Mansion' 'PARANOIHELL'
#  'Panmorphia' 'Eselmir and the five magical gifts'
#  'Surprise Mechanic: The Gaming Trivia']
#
# Game Title: Christmas Cats Revenge
# Recommended: ['Naughty Elves - Christmas puzzle game' 'Hidden Paws'
#  "Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-"
#  'Cats are Liquid - A Better Place'
#  'Cats are Liquid - A Light in the Shadows']
#
# Game Title: Cinco Paus
# Recommended: ['Animal Lover' 'Hero Generations' 'Pixel Session Vol.1'
#  'RogueCraft Squadron' 'if not us']
#
# Game Title: Circa Infinity
# Recommended: ['DROID7' 'TAMASHII' 'Star Escape' 'Pichon!' 'Captain MaCaw']
#
# Game Title: Clam Man
# Recommended: ['God, I Hate Wasps (1.03)' 'The Old Man + Extra chapter'
#  'All You Can Eat' 'Karambola' 'Labyrinth of Wild Abyss']
#
# Game Title: Clash of Coins
# Recommended: ['Bomsy' 'DANGEROUS DUELS' 'Nuvoloso' 'GourMelee' 'SHNIPERS']
#
# Game Title: Clean ATTACK!
# Recommended: ['Warden: Melody of the Undergrowth' 'I want to be a Triangle' 'Served'
#  'Spectres of the Cold' 'Over Run']
#
# Game Title: Clouds of Fire: Blazing Skies
# Recommended: ['Hyper Sentinel' 'OMEGANAUT' 'Cat Ace' 'Gun Rounds' 'Task Force Kampas']
#
# Game Title: Cluster Gun
# Recommended: ['Super Platformer Gun' 'Color Jumper' 'Dreaming Sarah' 'Gambol'
#  'MONUMENTAL FAILURE']
#
# Game Title: Code 7 - Episodes 2 & 3 Available Now
# Recommended: ['Eye of Ra' 'Your Future Self' 'Retrace' 'IMMURE' 'The Space Between']
#
# Game Title: Codemancer
# Recommended: ['Silicon Zeroes' 'Gladiabots' 'Autumn' 'No More Kings'
#  "Luna's Wandering Stars"]
#
# Game Title: Collared
# Recommended: ['Tales from the Road' 'Portal Dogs' 'Perspectrum' 'Rulent Tower VR'
#  'TAMASHII']
#
# Game Title: Color Cannons+
# Recommended: ['Bomsy' 'Turn-Based Champion' 'SHNIPERS' 'Speed Farmers' 'GourMelee']
#
# Game Title: Color Jumper
# Recommended: ['adjacency' 'Binaries' 'Feud' 'RYB'
#  'Cats are Liquid - A Light in the Shadows']
#
# Game Title: Combo Postage
# Recommended: ['They Come From Uranus!' 'Infiniboss' 'Ghost Grab 3000' 'Inkanians'
#  "Switch 'N' Shoot"]
#
# Game Title: Come Back: Chapter 1
# Recommended: ['Towayami' 'Without Escape' 'Winterlore I' 'Panmorphia' 'Veritas']
#
# Game Title: Concentric
# Recommended: ['Theorem' 'monad' 'SOMOS' 'adjacency' 'Nano Driller']
#
# Game Title: Conversations With Emma
# Recommended: ["Dialogue: A Writer's Story" '12 Labors' 'Far from Noise' 'Serre'
#  'Can Androids Pray: Red']
#
# Game Title: Conversations With My Anxiety
# Recommended: ['Talk To Me' 'Doodle Date' 'songs and flowers' 'Prince of Cats'
#  'Meeting in the Flesh']
#
# Game Title: Cook, Serve, Delicious! 2!!
# Recommended: ['Speed Farmers' 'U.F.O - Unfortunately Fortunate Organisms'
#  'Hi-Score Boi' 'BFF or Die' 'Crate Punks']
#
# Game Title: Cope Island: Adrift
# Recommended: ['Remnants' 'Ominous!' 'Stellaxy' 'Project Kat' 'TinkerQuarry']
#
# Game Title: Corey Coolbrew
# Recommended: ['The Curse of Trasmoz' '8 Bit Space' "Jumpin' Jupiter : Prelude"
#  'Cecconoid' 'Pichon!']
#
# Game Title: Corinne Cross's Dead & Breakfast
# Recommended: ['Toaster Jam' 'I EAT MANTRAS FOR BREAKFAST' 'Project Kat' 'Hedera'
#  'Devtheism']
#
# Game Title: Cosmic Rochambo
# Recommended: ['Wave to the People' 'STOWAWAY' 'BasketBelle' 'Neon Valley: Revenge'
#  'NeoLite']
#
# Game Title: Cosmonaut
# Recommended: ['GRAVITY FIGHTERS' "Luna's Wandering Stars" 'Crashed Lander'
#  'Deeper Into Space' 'Escape Room Simulator - Alpha Access']
#
# Game Title: Cotrio
# Recommended: ['Affinity' 'adjacency' 'Theorem' 'Desert Mothers' 'Soundodger+']
#
# Game Title: Crashed Lander
# Recommended: ['GRAVITY FIGHTERS' 'Perpetuum Mobile' 'Volo Airsport' 'Rulent Tower VR'
#  'These Lands']
#
# Game Title: Crate Punks
# Recommended: ['Antistatic' 'Wild Woods' 'SHNIPERS' 'BFF or Die' 'Joggernauts']
#
# Game Title: Crescent Loom
# Recommended: ['ART SQOOL' 'Quench' 'Mendel' 'Cromwell' 'Remnants']
#
# Game Title: Crest - an indirect god game
# Recommended: ['Intelligent Design: An Evolutionary Sandbox'
#  'Throw Cubes into Brick Towers To Collapse Them' 'Mendel' 'Ryza Roads'
#  'Dwerg Saga']
#
# Game Title: Croissants
# Recommended: ['HubWorld' 'Astæria' 'Isolation Story' 'nullpointer'
#  'NIGHT OF THE CONSUMERS']
#
# Game Title: Cromwell
# Recommended: ['Towertale' 'Inverness Nights' 'Flufftopia' 'Ominous!'
#  'Jam and the Mystery of the Mysteriously Spooky Mansion']
#
# Game Title: Crystal Control II
# Recommended: ['Jet Buster' 'Miles Infernum' 'Super Ledgehop: Double Laser' 'SHNIPERS'
#  'JUMPGRID']
#
# Game Title: Crystal Story: Awakening
# Recommended: ['Danger Crew' 'Stophat' 'Stellaxy' 'Crystal Control II' 'VIDEGOAME']
# Game Title: Crystal Towers 2
# Recommended: ['Semblance' 'LaserCat' 'Crystal Control II' 'Pichon!'
#  'Throw Cubes into Brick Towers To Collapse Them']
#
# Game Title: Cube Rampage
# Recommended: ['SUPER CUBE ATTACK' 'Snake Blocks' 'Halloween Forever' 'Theorem'
#  'Galactic Wars']
#
# Game Title: Cubefall
# Recommended: ['They Come From Uranus!' 'Infiniboss' "Switch 'N' Shoot" 'EVADER'
#  'Over Run']
#
# Game Title: Cuckoo Castle
# Recommended: ['Tiny Dangerous Dungeons' "Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-"
#  'Aerannis' 'Vision Soft Reset' 'Gumgem']
#
# Game Title: Curse of the Crescent Isle DX
# Recommended: ['Astral Defense' 'Super Slime Arena' 'Gumgem' 'GRAVITY FIGHTERS'
#  'Blitz Breaker']
#
# Game Title: Cycle 28
# Recommended: ['Cat Ace' 'Super Ledgehop: Double Laser' 'Hyper Sentinel' 'Block Out'
#  'Zenodyne R']
#
# Game Title: D.M.T
# Recommended: ['Guide of the Butterfly' 'Shutter Stroll'
#  'The Indifferent Wonder of an Edible Place' 'Walking Tourist'
#  'Fugue in Void']
#
# Game Title: DANGEROUS DUELS
# Recommended: ['Clash of Coins' 'Turn-Based Champion' 'Butsbal' 'Penguins Arena'
#  'C.M.Y.K']
#
# Game Title: DATA LOSS
# Recommended: ['Eves Drop' 'Realm of the Ghost King' 'Beglitched' "Old Man's Journey"
#  'Quadrilateral Cowboy']
#
# Game Title: DERE EVIL .EXE
# Recommended: ['OneShot' 'TAMASHII' 'please' 'Please Follow' 'Hedera']
#
# Game Title: DON'T WAKE THE NIGHT
# Recommended: ['The Night Fisherman' 'Winterlore I' 'Without Escape'
#  'The Alabaster Donut Farm' 'Panmorphia']
#
# Game Title: DROID7
# Recommended: ['Star Escape' 'Escape Room Simulator - Alpha Access' 'Circa Infinity'
#  'Splinter Zone' 'Escape from Life Inc']
#
# Game Title: DROPSHIP
# Recommended: ['Nest Lander' 'A Hole New World' 'On Rusty Trails' 'Inkanians'
#  'Crashed Lander']
#
# Game Title: DYO
# Recommended: ['Labyrinth of Wild Abyss' 'BFF or Die' 'Joggernauts' 'Luminous Labyrinth'
#  'Crate Punks']
#
# Game Title: Daemon Detective Gaiden II
# Recommended: ['Rogues Like Us' 'Nina Aquila: Legal Eagle, Chapter II: "Broken Wings"'
#  'Detective Bot' 'Double Cross' 'They Bleed Pixels']
#
# Game Title: Daemon Detective Racing Zero
# Recommended: ['Ryza Roads' 'No Wheels Racing' 'Vienna Automobile Society'
#  "Rock n' Rush: Battle Racing" 'CARBAGE']
#
# Game Title: Daily Chthonicle
# Recommended: ['Detective Bot' "Echoes of the Fey Episode 1: The Fox's Trail"
#  'Ring of Fire Prologue' 'The Whisperer in Darkness'
#  'Dominique Pamplemousse in "It\'s All Over Once The Fat Lady Sings!"']
#
# Game Title: Danger Crew
# Recommended: ['Crystal Story: Awakening' 'Danger Zone Friends' 'Stophat'
#  'Depth of Extinction' 'Stellaxy']
#
# Game Title: Danger Zone Friends
# Recommended: ['Epic Battle Fantasy 4' 'Soma Spirits: Rebalance' 'Danger Crew'
#  'Brave Hero Yuusha EX'
#  'I Have Low Stats But My Class Is "Leader", So I Recruited Everyone I Know To Fight The Dark Lord']
#
# Game Title: Darkest Wave
# Recommended: ['Cycle 28' 'Hyper Sentinel' 'Clouds of Fire: Blazing Skies' 'Cat Ace'
#  'Wave to the People']
#
# Game Title: David
# Recommended: ['Walden, a game' 'Flat Kingdom' 'Emberlight' 'The Hero of Budgie Island'
#  'DERE EVIL .EXE']
#
# Game Title: Dawn of a Soul
# Recommended: ['Cardinal Chains' 'adjacency' 'Affinity' 'GNOG' 'Puzzle Puppers']
#
# Game Title: Dawndusk Dream Sewer
# Recommended: ['Cardiac' 'EAT GIRL' 'ZEPTON' 'The Space Between' 'soundStrider']
#
# Game Title: Daydreamour
# Recommended: ['SilverQuest Gaiden' 'TEOCALLI'
#  'The Adventures of Elena Temple: Definitive Edition' 'COMPEL'
#  "Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-"]
#
# Game Title: Dead 4 Dress
# Recommended: ['Halloween Forever' 'Bunny Hill Horror' 'All Haze Eve'
#  'Make your Adventure' 'Dead Pixels: The 8-bit zombie sim.']
#
# Game Title: Dead Pixels: The 8-bit zombie sim.
# Recommended: ['Grindhouse Games Volume I' 'Dead 4 Dress' 'Galactic Wars' 'Over Run'
#  'BulletHell Planes']
#
# Game Title: Dear Mariko
# Recommended: ['Project Kat' 'Blue Rose' 'Towayami' 'Ominous!' 'Towertale']
#
# Game Title: Death Game+
# Recommended: ['Quible Sphere' 'Soundodger+' 'Toaster Jam' 'Micron' 'Hyperplex 3D']
#
# Game Title: Death and Taxes
# Recommended: ['Retrace' "Death's Life" 'Speed Dating for Ghosts'
#  'MetaWare High School (Demo)' 'Broken Minds']
#
# Game Title: Death's Life
# Recommended: ['A Wish Upon A Star' 'Death and Taxes' 'Without Escape' 'Towayami'
#  'The Guilt and the Shadow']
#
# Game Title: Death? Preposterous! - A Non-violent RPG
# Recommended: ['Ominous!' 'Remnants' 'Book of Eos' 'ARGH-P-G'
#  'Benjamin of Blackstone Edge']
#
# Game Title: Deck Defenders [Demo Available!]
# Recommended: ['Nine Nines' '9 Till Void' 'The Land of Glass' 'MonGirl Tile'
#  'RogueCraft Squadron']
#
# Game Title: Dee Dum (Computer)
# Recommended: ['Stick Nightmare' 'Theorem' 'Perspectrum' 'Above: The Fallen'
#  'Silicon Zeroes']
#
# Game Title: Deeper Into Space
# Recommended: ['Atomic Heist' 'Space Duet™' 'Astral Defense' 'Rogue Rocks'
#  'SuperLuminauts']
#
# Game Title: Democratic Socialism Simulator
# Recommended: ['Quench' 'Bad Government' 'Guide of the Butterfly' 'D.M.T'
#  'Kalling Kingdom']
#
# Game Title: Depth of Extinction
# Recommended: ['Sverdheim' 'FLAMBERGE' 'Glitch Strike' 'ARGH-P-G' 'Hellenica']
#
# Game Title: Desastre Colectivo
# Recommended: ['String Tyrant' 'The Morrison Survival Game' '[SIBERIA]' 'MewnBase'
#  'Inner']
#
# Game Title: Desert Mothers
# Recommended: ['Cotrio' 'soundStrider' 'A Short Hike' 'THE ENIGMA MACHINE'
#  'The World Begins With You']
#
# Game Title: Desktop Goose
# Recommended: ['Desktop Meadow' 'Where is cat?' 'Vilmonic' 'Flewberry'
#  'He Plays the Piano']
#
# Game Title: Desktop Meadow
# Recommended: ['Desktop Goose' 'Best Garden' 'Flowerdrops' 'Even in Arcadia'
#  '#hasicontent']
#
# Game Title: Destiny Fails Us: A New Life
# Recommended: ['songs and flowers' 'Make It Last' 'Belong' 'Blue Rose'
#  'That Which Binds Us']
#
# Game Title: Destructivator 2
# Recommended: ['Zenohell' 'Blaster Bunny +' 'Zenodyne R' 'Outpost Horizon Station'
#  'Cycle 28']
#
# Game Title: Detective Bot
# Recommended: ['Daily Chthonicle' 'Detective Hank and the Golden Sneeze'
#  "Echoes of the Fey Episode 1: The Fox's Trail"
#  'Real Winners: Victoryball' 'BFF or Die']
#
# Game Title: Detective Hank and the Golden Sneeze
# Recommended: ['Detective Bot' "Echoes of the Fey Episode 1: The Fox's Trail"
#  'Ring of Fire Prologue' 'Daily Chthonicle'
#  'Jam and the Mystery of the Mysteriously Spooky Mansion']
#
# Game Title: Devtheism
# Recommended: ['Project Kat' 'Book of Eos' 'Tales Across Time' 'Ominous!' 'Remnants']
#
# Game Title: Dialogue: A Writer's Story
# Recommended: ['Far from Noise' 'Conversations With Emma' 'Tales From Windy Meadow'
#  'a new life.' 'Waiting for the Loop']
#
# Game Title: Diaries of a Spaceport Janitor
# Recommended: ['Trash wars' 'adjacency' 'Polymute' 'Cope Island: Adrift' 'forma.8']
#
# Game Title: Dimension Drive
# Recommended: ['Hyper Sentinel' 'GUNPIG: Firepower For Hire' "Switch 'N' Shoot"
#  'Flashover MegaSector' 'Drive to Hell']
#
# Game Title: Dinos In Space
# Recommended: ["Luna's Wandering Stars" 'Space Duet™' 'Pulstario' 'Shn!p' 'Little Comet']
#
# Game Title: Dis Pontibus
# Recommended: ['HexaCycle' 'Theorem' 'Affinity' 'Stellaxy' 'Gumgem']
#
# Game Title: Discovering Colors - Animals
# Recommended: ['Paint Game' 'Quench' 'Little Comet' 'KIDS' 'Arigatou, Ningen-san!']
#
# Game Title: Discsphere
# Recommended: ['BasketBelle' 'Infiniboss' 'Binary Heresy' 'Unfair Jousting Fair'
#  'Towertale']
#
# Game Title: Disobedient Sheep
# Recommended: ['Sheep Dreams Are Made of This' 'Sheepless Nights (Math cardgame)'
#  'Turn-Based Champion' 'Served' 'B.O.O.M. - You Win [Early Access]']
#
# Game Title: Distortion Nation
# Recommended: ['Serre' 'BAKED:MAGIC' 'By Your Side' 'Secret Little Haven'
#  'Highway Blossoms: Remastered']
#
# Game Title: Dogs Throwing Swords II: Three Barks To The Wind
# Recommended: ['Portal Dogs' 'Crystal Control II' 'Jet Buster' 'Dogurai'
#  'Miles Infernum']
#
# Game Title: Dogurai
# Recommended: ['Portal Dogs' 'Dogs Throwing Swords II: Three Barks To The Wind'
#  'Infiniboss' "Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-" 'Space Duet™']
#
# Game Title: Dominique Pamplemousse and Dominique Pamplemousse in "Combinatorial Explosion!"
# Recommended: ['Dominique Pamplemousse in "It\'s All Over Once The Fat Lady Sings!"'
#  'Yi and the Thousand Moons' 'Daily Chthonicle' 'Boa Retina' 'Fugue']
#
# Game Title: Dominique Pamplemousse in "It's All Over Once The Fat Lady Sings!"
# Recommended: ['Dominique Pamplemousse and Dominique Pamplemousse in "Combinatorial Explosion!"'
#  'Detective Bot' 'Daily Chthonicle' 'Yi and the Thousand Moons'
#  'Boa Retina']
#
# Game Title: Don't Move
# Recommended: ['MONUMENTAL FAILURE' 'Master Spy' 'LaserCat'
#  'The Adventures of Elena Temple: Definitive Edition' 'Pichon!']
#
# Game Title: Don't Take It Personally, I Just Don't Like You: The Camping Trip
# Recommended: ['Meeting in the Flesh' 'songs and flowers' 'Speed Dating for Ghosts'
#  'Love Hues! [Full Game]' 'Starlight Shores']
#
# Game Title: Doodle Date
# Recommended: ['Conversations With My Anxiety' 'Arcade Spirits' 'songs and flowers'
#  'Meeting in the Flesh' 'Prince of Cats']
#
# Game Title: Dorfromantik
# Recommended: ['Kalling Kingdom' 'Terri-Fried' 'The Quiet Sleep' 'Soldier of Fortune'
#  'MonGirl Tile']
#
# Game Title: Double Cross
# Recommended: ['Perspectrum' 'Super Platformer Gun' 'Zak' 'Daemon Detective Gaiden II'
#  'WILOO']
#
# Game Title: Dr. Langeskov, The Tiger, And The Terribly Cursed Emerald: A Whirlwind Heist
# Recommended: ['Fugue in Void' 'Astæria' 'ISLANDS: Non-Places' 'EAT GIRL'
#  'Annwn: the Otherworld']
#
# Game Title: Dragondot 3
# Recommended: ['Flat Kingdom' "Lenna's Inception" 'The Last Librarian' 'Fossil Hunters'
#  'Plunge']
#
# Game Title: Drake
# Recommended: ['Captain MaCaw' 'Adventures of a Radish(Full)' 'Blaster Bunny +'
#  '[SIBERIA]' 'Pulstario']
#
# Game Title: Dreaming Sarah
# Recommended: ['Wishing Sarah' 'LaserCat' 'The Space Between' 'Gambol' 'Fumiko!']
#
# Game Title: DriftKing 2D
# Recommended: ['Bomb Dolls' 'Ghost Grab 3000' 'WretchWorks Arcade Pack' 'Alien Life Lab'
#  'Infiniboss']
#
# Game Title: Drive to Hell
# Recommended: ['Dimension Drive' 'Miles Infernum' 'Jet Buster' 'Blast Rush'
#  'Super Ledgehop: Double Laser']
#
# Game Title: Drones, The Human Condition
# Recommended: ['Task Force Kampas' 'Hyper Sentinel' 'Sonar Smash' 'Receiver' 'Zenohell']
#
# Game Title: Drum Brain
# Recommended: ['Guitar Fretter' '[HTC Vive] VR Drum Studio' 'Soundodger+' 'Micron'
#  'Stage Fright']
#
# Game Title: Dry Drowning
# Recommended: ['Broken Minds' 'HEADLINER' 'Retrace' 'Ring of Fire Prologue'
#  'VEKTOR 2089']
#
# Game Title: Dual Pong
# Recommended: ['Laser Paddles' 'Butsbal' 'BasketBelle' 'Super Dunkman' 'Discsphere']
#
# Game Title: Duck in Town - A Rising Knight
# Recommended: ['Last Knight: Rogue Rider Edition' 'Boreal Tenebrae'
#  'Eselmir and the five magical gifts' 'Panmorphia' 'Legend of Hand']
#
# Game Title: Dujanah
# Recommended: ['NO THING' 'ISLANDS: Non-Places' 'Nano Driller' 'The Real Texas'
#  'Ghost Story']
#
# Game Title: Dungeon Nightmares II - The Memory
# Recommended: ['ARGH-P-G' 'Emberlight' 'Possession' 'SilverQuest Gaiden' 'MidBoss']
#
# Game Title: Dungeons & Lesbians
# Recommended: ['Prince of Cats' 'songs and flowers' 'Meeting in the Flesh'
#  "Don't Take It Personally, I Just Don't Like You: The Camping Trip"
#  'Arcade Spirits']
#
# Game Title: Dungeons of Loot
# Recommended: ['Hyperspace Dogfights' 'Ephemeral Tale' 'Loot Rascals' 'Binary Heresy'
#  'Catacombs 1: Demon War']
#
# Game Title: Dusk Child
# Recommended: ['Soldier of Fortune' 'NeoLite' 'Plana Gravatatis' 'Patches Of Adventure'
#  'Rasternauts']
#
# Game Title: Dwerg Saga
# Recommended: ['RogueCraft Squadron' 'Crest - an indirect god game'
#  'Annwn: the Otherworld' 'Erth' 'Mass Warfare']
#
# Game Title: EAT GIRL
# Recommended: ['Stophat' 'Pixel Session Vol.1' 'Us Lovely Corpses' 'MORFOSI｜莫法西'
#  'The Space Between']
#
# Game Title: ECON - Elemental Connection
# Recommended: ['Feud' 'No More Kings' "Lew Pulsipher's Doomstar" 'Turn-Based Champion'
#  'Chess Mix']
# Game Title: EMUUROM
# Recommended: ['Midnight Manor' 'Remnants' 'Swung' '8 Bit Space' 'Miasma Caves']
#
# Game Title: ETHEREAL
# Recommended: ['adjacency' 'stop' 'Qavo' 'Color Jumper' 'The Search']
#
# Game Title: EVADER
# Recommended: ['Retromancer' 'They Come From Uranus!' "Switch 'N' Shoot" 'Timebomb'
#  'Infiniboss']
#
# Game Title: EXTREME MEATPUNKS FOREVER
# Recommended: ['Can Androids Pray: Red' 'Arcade Spirits' 'Blind Men' 'a new life.'
#  '12 Labors']
#
# Game Title: Ecchi Sketch: Draw Cute Girls Every Day! (All Ages Ver)
# Recommended: ['Sweet Volley High (All Ages ver)'
#  "as long as we're together: magical girls sweet & pure" 'BAKED:MAGIC'
#  'songs and flowers' 'MonGirl Tile']
#
# Game Title: Echoes of the Fey Episode 1: The Fox's Trail
# Recommended: ['Blue Rose' 'Detective Bot' 'Ring of Fire Prologue'
#  'Detective Hank and the Golden Sneeze' 'Daily Chthonicle']
#
# Game Title: Eizoku
# Recommended: ['IMMURE' 'please' 'Please Follow' 'Inner' 'Grime & Gaslight']
#
# Game Title: El Interrogatorio
# Recommended: ['No cortarás a tu hermana con el filo de esta espada'
#  'Tales from the Road' 'The Whisperer in Darkness' 'Bunny Hill Horror'
#  '12 Labors']
#
# Game Title: El Tango de la Muerte
# Recommended: ['Stage Fright' 'Micron' 'Soundodger+'
#  'No cortarás a tu hermana con el filo de esta espada' 'inSynch']
#
# Game Title: EleMetals: Death Metal Death Match
# Recommended: ['Clash of Coins' 'DANGEROUS DUELS' 'Oh No! Bugs!' 'SuperLuminauts'
#  'SPACEBEEF']
#
# Game Title: Elephant Hunter Hunter
# Recommended: ['Garrison Gauntlet' 'stop' 'Astral Defense' 'Zenodyne R' 'Galactic Wars']
#
# Game Title: Emberlight
# Recommended: ['ARGH-P-G' 'Possession' 'Dungeon Nightmares II - The Memory' 'MidBoss'
#  'SilverQuest Gaiden']
#
# Game Title: Empyrean Frontier
# Recommended: ['From Orbit' 'RogueCraft Squadron' 'Annwn: the Otherworld' 'Mass Warfare'
#  'Interstellaria']
#
# Game Title: Enc and the Flying Machine
# Recommended: ['Serre' 'Distortion Nation' 'Us Lovely Corpses' 'Secret Little Haven'
#  'Highway Blossoms: Remastered']
#
# Game Title: Ephemeral Tale
# Recommended: ['Dungeons of Loot' 'Glitch Strike' 'Book of Eos'
#  'NEXT JUMP: Shmup Tactics' 'Turn Chase']
#
# Game Title: Epic Battle Fantasy 4
# Recommended: ['Danger Zone Friends' 'Legend of Hand' 'Hellenica'
#  'Soma Spirits: Rebalance' 'Book of Eos']
#
# Game Title: Equaboreal 12.21
# Recommended: ['Winter Bundle (ENG)' 'Even in Arcadia' 'Hidden Paws' '12 Labors'
#  'Wheels of Aurelia']
#
# Game Title: Erth
# Recommended: ['Ollie & Bollie: Outdoor Estate' 'Mendel' 'Brushwood Buddies'
#  'Intelligent Design: An Evolutionary Sandbox' 'Odd Realm']
#
# Game Title: Escape Room Simulator - Alpha Access
# Recommended: ['Forgiveness : Escape Room' "Marie's Room" 'DROID7' 'The White Door'
#  'The Red Door']
#
# Game Title: Escape from Life Inc
# Recommended: ['The Guilt and the Shadow' 'Brathian' 'Nótt & Dagr' 'Above: The Fallen'
#  'Toaster Jam']
#
# Game Title: Escaped Chasm
# Recommended: ['MORTAGH: COLLECTOR of SOULS' 'Us Lovely Corpses' 'Project Kat'
#  'Jimmy and the Pulsating Mass' 'Orison of Mercury']
#
# Game Title: Escort Yourself Out
# Recommended: ["In My Friend Carrie's Car" 'Memoir En Code: Reissue' 'down.' '[SIBERIA]'
#  'ADLENGINE - Roleplay / Text Adventure Engine']
#
# Game Title: Eselmir and the five magical gifts
# Recommended: ['Pendula Swing: The Complete Journey' 'Panmorphia'
#  'Ouroboros: The Sacrifice' 'The Guilt and the Shadow' 'Legend of Hand']
#
# Game Title: Even in Arcadia
# Recommended: ['Equaboreal 12.21' 'The Night Journey' 'Fugue in Void' 'Astæria'
#  'Eye of Ra']
#
# Game Title: Eves Drop
# Recommended: ['Quadrilateral Cowboy' 'DATA LOSS' 'Beglitched' 'NOISE1' 'nullpointer']
#
# Game Title: Explobers
# Recommended: ['Perspectrum' "Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-"
#  'Super Win the Game' 'Blitz Breaker' 'Fateful Lore']
#
# Game Title: Extreme Mining
# Recommended: ['Space Mining Clicker' 'Rogue Rocks' 'Bitcoin Miner: Remastered'
#  'EXTREME MEATPUNKS FOREVER' 'Behind the Masc']
#
# Game Title: Eye of Ra
# Recommended: ['Helium Rain' "Luna's Wandering Stars" 'The Alabaster Donut Farm'
#  'Pulstario' 'Voyageur']
#
# Game Title: FLAMBERGE
# Recommended: ['Depth of Extinction' 'Glitch Strike' 'NEXT JUMP: Shmup Tactics'
#  'Steam Marines 2' '9 Till Void']
#
# Game Title: FLAT FORM FIGHTER
# Recommended: ['Antistatic' 'SHNIPERS' 'Crate Punks' 'Turn-Based Champion'
#  'Clash of Coins']
#
# Game Title: FORGET THE BRAKES!
# Recommended: ['No Brakes Valet' 'perfect park' 'Locomancer' 'That Which Binds Us'
#  'Peace of Mind']
#
# Game Title: FRIDAY NIGHT BULLET ARENA
# Recommended: ['Jet Buster' 'SHNIPERS' 'Clash of Coins' 'Bomsy' 'C.M.Y.K']
#
# Game Title: FROG
# Recommended: ['Un Pas Fragile' 'Your Future Self' 'ViCam' 'Online Simulator'
#  'Monster Pub Chapter 1']
#
# Game Title: Factory Hiro
# Recommended: ['Refactor' 'Micron' 'Stage Fright' 'iZBOT' 'Orison of Mercury']
#
# Game Title: Falling Skies
# Recommended: ['Cycle 28' 'Clouds of Fire: Blazing Skies' 'Hyper Sentinel'
#  'Astral Defense' 'Super Ledgehop: Double Laser']
#
# Game Title: Fantom Feast
# Recommended: ['probability 0' 'EAT GIRL' 'Ghost Grab 3000' 'WretchWorks Arcade Pack'
#  'Ghost Story']
#
# Game Title: Far from Noise
# Recommended: ["Dialogue: A Writer's Story" 'Conversations With Emma' 'The Deer God'
#  'Retrace' 'Speed Dating for Ghosts']
#
# Game Title: Fate Tectonics
# Recommended: ['Choice Chamber' 'Depth of Extinction' 'Astral Defense' 'Emberlight'
#  'Zenodyne R']
#
# Game Title: Fateful Lore
# Recommended: ['Pillars of Dust' 'Danger Zone Friends' 'Galactic Wars'
#  'Turn-Based Champion' 'Soma Spirits: Rebalance']
#
# Game Title: Feud
# Recommended: ["Lew Pulsipher's Doomstar" 'Glitch Strike' 'Attrition: Tactical Fronts'
#  'Flash Point: Fire Rescue' 'Turn Chase']
#
# Game Title: Fish Fly Fever
# Recommended: ['Guppy' 'Super Ledgehop: Double Laser' 'Jet Buster' 'Cat Ace'
#  'Hyper Sentinel']
#
# Game Title: Flash Point: Fire Rescue
# Recommended: ['Feud' "Lew Pulsipher's Doomstar" 'Attrition: Tactical Fronts'
#  'Glitch Strike' 'Turn-Based Champion']
#
# Game Title: Flashover MegaSector
# Recommended: ['Those Spacecrafts' 'Hyper Sentinel' 'Task Force Kampas'
#  'Dimension Drive' 'Shoot Shoot Mega Pack']
#
# Game Title: Flat Kingdom
# Recommended: ['Dragondot 3' 'WitchWay' 'Retrace' 'stop' 'Curse of the Crescent Isle DX']
#
# Game Title: Flewberry
# Recommended: ['Mon-cuties for All' 'Vilmonic' 'Crashed Lander' 'Petty Puny Planet'
#  'Peck N Run']
#
# Game Title: Flowerdrops
# Recommended: ['Spring Falls' 'Glittermitten Grove' 'songs and flowers' 'Affinity'
#  'plant daddy']
#
# Game Title: Flufftopia
# Recommended: ['Space Mining Clicker' 'Cardinal Chains' 'He Plays the Piano'
#  'The Night Journey' 'Towertale']
#
# Game Title: Flux
# Recommended: ['Sun Dogs' 'Soundodger+' 'inSynch' 'VEKTOR 2089' 'Micron']
#
# Game Title: Fools Fortune
# Recommended: ['Soldier of Fortune' 'NeoLite' 'Towertale' '9 Till Void'
#  'Knights of the Card Table']
#
# Game Title: Football Drama
# Recommended: ['Neocolonialism' 'Feud' 'No Pineapple Left Behind' '9 Till Void'
#  'Glitch Strike']
#
# Game Title: Forever Lost: Episode 1
# Recommended: ['Forever Lost: Episode 3' 'Forever Lost: Episode 2' 'Towayami'
#  'Without Escape' "MicroHorrorArcade Trilogy I - Andy's Story"]
#
# Game Title: Forever Lost: Episode 2
# Recommended: ['Forever Lost: Episode 3' 'Forever Lost: Episode 1' 'Towayami'
#  'Without Escape' 'Sagebrush']
#
# Game Title: Forever Lost: Episode 3
# Recommended: ['Forever Lost: Episode 1' 'Forever Lost: Episode 2' 'Towayami'
#  'Without Escape' "MicroHorrorArcade Trilogy I - Andy's Story"]
#
# Game Title: Forgiveness : Escape Room
# Recommended: ['Escape Room Simulator - Alpha Access' "Marie's Room" 'The Red Door'
#  'The White Door' '樺ヶ原脱出 - Escape from Kabagahara']
#
# Game Title: Fortune-499
# Recommended: ['Your Future Self' 'MULTIPUCK' "Tessa's Ark: Chapter 1"
#  'Monster Pub Chapter 2' 'Monster Pub Chapter 3']
#
# Game Title: Fossil Echo
# Recommended: ['HATCH' 'Blitz Breaker' 'Abomination Tower' 'Nine Nines'
#  'Stick Nightmare']
#
# Game Title: Fossil Hunters
# Recommended: ['BFF or Die' 'GourMelee' 'Crate Punks' 'Sokoban Land DX' 'Wild Woods']
#
# Game Title: Four Horsemen
# Recommended: ['Benjamin of Blackstone Edge' 'Destiny Fails Us: A New Life'
#  'One-Eyed Lee: Prologue' 'Starlight Shores' 'Moonstone Deep']
#
# Game Title: Four Sided Fantasy
# Recommended: ['Blue Rose' 'Ouroboros: The Sacrifice' 'Cotrio' 'Subterrarium' 'TAMASHII']
#
# Game Title: From Orbit
# Recommended: ['Empyrean Frontier' 'Nigel' 'RogueCraft Squadron' 'Star and Light 1.0'
#  'Pulstario']
#
# Game Title: Fugue
# Recommended: ['Parallax' 'Soundodger+' 'Yi and the Thousand Moons' 'Hidden Folks'
#  'A Light Long Gone']
#
# Game Title: Fugue in Void
# Recommended: ['Astæria' 'The Night Journey' 'Peak Bleak Blues (and other moods)'
#  'Stars Die'
# ...
#  'Real Winners: Victoryball' 'GourMelee' 'Pixelry']
#
# Game Title: Ungrounded
# Recommended: ['SAI' 'Sun Dogs' 'Affinity' 'stop' 'Autumn']
#
# Game Title: Unobelisk
# Recommended: ['String Tyrant' 'Inner' 'Grime & Gaslight' 'MewnBase' '[SIBERIA]']
#
# Game Title: Us Lovely Corpses
# Recommended: ['Serre' 'EAT GIRL' 'Celestial Hacker Girl Jessica'
#  'Little Bug (full version)' 'Dear Mariko']
#
# Game Title: Utopias: Navigating Without Coordinates
# Recommended: ['Peak Bleak Blues (and other moods)' 'Fugue in Void' 'Remnants'
#  'Walking Tourist' 'Kingdom Ka']
#
# Game Title: VEKTOR 2089
# Recommended: ['Dry Drowning' 'Flux' 'Sun Dogs' 'Witchball'
#  'Daemon Detective Racing Zero']
#
# Game Title: VIDEGOAME
# Recommended: ['Dungeon Nightmares II - The Memory' 'ARGH-P-G' 'SilverQuest Gaiden'
#  'A Magical Tale: Cavern Crawler' 'Roguescape']
#
# Game Title: VIRTUA BLINDS
# Recommended: ['Star and Light 1.0' 'A Light Long Gone' 'Keep It Together' 'From Orbit'
#  'Cell Tune']
#
# Game Title: Vegetables Deluxe C64
# Recommended: ["Hunter's Moon Remastered" 'BRKÖUT' 'Garden Match' 'Six Match'
#  'Monster Match']
#
# Game Title: Veiled
# Recommended: ['IMMURE' 'Towayami' 'Seduce Me The Complete Story' 'Grime & Gaslight'
#  'MORFOSI｜莫法西']
#
# Game Title: VekWars
# Recommended: ['These Lands' 'Perpetuum Mobile' 'OMEGANAUT' 'GNOG' 'BloodBlast VR']
#
# Game Title: Verdant Skies
# Recommended: ['Make your Adventure' 'Stealth Fishing' 'Belong' 'Prince of Cats'
#  'Village Monsters']
#
# Game Title: Veritas
# Recommended: ['Winterlore I' 'Retrace' 'The Fall of Lazarus'
#  'Escape Room Simulator - Alpha Access' 'The Missing Locksmith']
#
# Game Title: ViCam
# Recommended: ['Shutter Stroll' '2d flight simulator' 'FROG'
#  'Whipped And Steamy • Cosplay Café' 'Bestiary']
#
# Game Title: Vienna Automobile Society
# Recommended: ['Daemon Detective Racing Zero' 'Ryza Roads' 'Feud' 'No Wheels Racing'
#  "Rock n' Rush: Battle Racing"]
#
# Game Title: Vignettes
# Recommended: ['IGEO' 'The House on Holland Hill' 'Magic Trick' 'A Wish Upon A Star'
#  "A Snake's Tale"]
#
# Game Title: Village Monsters
# Recommended: ['Cell Tune' 'Intelligent Design: An Evolutionary Sandbox'
#  'Stealth Fishing' 'Verdant Skies' 'Escape from Life Inc']
#
# Game Title: Vilmonic
# Recommended: ['Intelligent Design: An Evolutionary Sandbox' 'Mendel' 'Cell Tune'
#  'Mon-cuties for All' 'Flewberry']
#
# Game Title: Vincent: The Secret of Myers | 文森：梅尔斯的秘密
# Recommended: ['The Secret of Tremendous Corporation' 'Without Escape'
#  'Forever Lost: Episode 2' 'Forever Lost: Episode 3' 'Bunny Hill Horror']
#
# Game Title: Vision Soft Reset
# Recommended: ['Aerannis' 'Visual Out' 'Mable & The Wood' 'VIDEGOAME' 'Cuckoo Castle']
#
# Game Title: Visual Out
# Recommended: ['Vision Soft Reset' 'Mable & The Wood' 'Aerannis'
#  'Neon Blight: Final Demo' 'Hedera']
#
# Game Title: Viv and Bob
# Recommended: ['Wishing Sarah' 'cityglitch' 'TAMASHII' 'WitchWay'
#  'Adventures of a Radish(Full)']
#
# Game Title: Void Runner
# Recommended: ['Timebomb' 'Void Wisp' 'Space Madness' 'Blitz Breaker' 'Shadowcut']
#
# Game Title: Void Wisp
# Recommended: ['Timebomb' 'Void Runner' 'EVADER' 'They Come From Uranus!' 'Infiniboss']
#
# Game Title: Volo Airsport
# Recommended: ['Crashed Lander' 'Perpetuum Mobile' 'Rulent Tower VR' 'These Lands'
#  'Antigas Constelações (sobre a Vila Itororó)']
#
# Game Title: VoltAge:Genesis
# Recommended: ['Moonstone Deep' 'Benjamin of Blackstone Edge' 'Book of Eos' 'Silk'
#  'Myth Bearer']
#
# Game Title: Voyageur
# Recommended: ['Stellaxy' 'Eye of Ra' 'Sverdheim' 'The Fall of Lazarus' 'Sun Dogs']
#
# Game Title: WATER'S FINE
# Recommended: ['nullpointer' 'No Delivery' 'Hyperspace Dogfights' 'Hotel Paradise'
#  'Emberlight']
#
# Game Title: WE ARE DOOMED
# Recommended: ['Neon Valley: Revenge' 'GUNPIG: Firepower For Hire' 'Bleed' 'Rym 9000'
#  'ACIDTRIP']
#
# Game Title: WILOO
# Recommended: ['Perspectrum' 'Blitz Breaker' 'Super Bernie World' 'TAMASHII'
#  'Bubbles the Cat']
#
# Game Title: Waiting for the Loop
# Recommended: ['As We Know It' 'warm' 'Recording the Predestined Time' 'The Search'
#  'Prince of Cats']
#
# Game Title: Wakamarina Valley, New Zealand
# Recommended: ['Quiet as a Stone' "Marie's Room" 'Shutter Stroll' 'The Fall of Lazarus'
#  'The Search']
#
# Game Title: Walden, a game
# Recommended: ['Peak Bleak Blues (and other moods)' 'Fugue in Void' 'The Search'
#  'Guide of the Butterfly' 'Isolation Story']
#
# Game Title: Walking Tourist
# Recommended: ['Peak Bleak Blues (and other moods)' 'please' 'Please Follow' 'D.M.T'
#  'soundStrider']
#
# Game Title: Wampus
# Recommended: ['Micro Mages' 'Grindhouse Games Volume I' 'iZBOT'
#  'Ouroboros: The Sacrifice' 'Patches Of Adventure']
#
# Game Title: Warden: Melody of the Undergrowth
# Recommended: ['I want to be a Triangle' 'Spectres of the Cold' 'Clean ATTACK!'
#  'Potato Thriller (Classic)' 'NeoLite']
#
# Game Title: Watch Me Jump
# Recommended: ['BasketBelle' 'Tales From Windy Meadow' '12 Labors' 'Super Dunkman'
#  'That Which Binds Us']
#
# Game Title: Wave to the People
# Recommended: ['Darkest Wave' 'The Big Wave: Colorblind & Deaf Friendly Puzzle Game'
#  'Cosmic Rochambo' 'Night in the Storm' 'Central Limit Theorem']
#
# Game Title: WaveCrash!!
# Recommended: ['Blockara' 'Garden Match' 'Monster Match' 'Clash of Coins' 'Six Match']
#
# Game Title: What Isn't Saved (will be lost)
# Recommended: ['A Normal Lost Phone' 'Forgiveness : Escape Room'
#  'Legend of the Lost Dragons' 'Imperishable Memories' 'GNOG']
#
# Game Title: What happened to Survey Team 4?
# Recommended: ['Wooden Hearts' 'Location Withheld' 'STOWAWAY' 'Grime & Gaslight'
#  'The Away Team']
#
# Game Title: Wheels of Aurelia
# Recommended: ['No Wheels Racing' 'Daemon Detective Racing Zero' 'Ryza Roads' 'CARBAGE'
#  'Equaboreal 12.21']
#
# Game Title: Where is cat?
# Recommended: ['KIDS' 'Wooden Hearts' 'Penguins Arena' 'Little Comet' 'Desktop Goose']
#
# Game Title: Whipped And Steamy • Cosplay Café
# Recommended: ['Destiny Fails Us: A New Life' 'Best Garden' 'songs and flowers'
#  "Don't Take It Personally, I Just Don't Like You: The Camping Trip"
#  'Starlight Shores']
#
# Game Title: Who Killed My Father Academy!
# Recommended: ['songs and flowers' 'Belong' 'Animal Lover' 'Meeting in the Flesh'
#  'Blind Men']
#
# Game Title: Wide Ocean Big Jacket
# Recommended: ['Thing-in-Itself' 'The Guilt and the Shadow' 'Bonbon' 'a new life.'
#  'Escape from Life Inc']
#
# Game Title: Widget Satchel
# Recommended: ['Dusk Child' 'Plana Gravatatis' 'Soldier of Fortune' 'NeoLite' 'WILOO']
#
# Game Title: Wild Woods
# Recommended: ['BFF or Die' 'Crate Punks' 'GourMelee' 'Joggernauts'
#  'Go Morse Go! Arcade Edition']
#
# Game Title: Windosill
# Recommended: ['Mastermind Classic' 'Chook & Sosig: Walk the Plank'
#  'Jam and the Mystery of the Mysteriously Spooky Mansion'
#  'The Adventures of Elena Temple: Definitive Edition'
#  'That Puzzle Game Everyone Knows']
#
# Game Title: Winter Bundle (ENG)
# Recommended: ['10 in 1 game-a-week bundle!' 'Equaboreal 12.21' 'Hidden Paws'
#  'Jupitron Game Collection Vol.1' 'ECON - Elemental Connection']
#
# Game Title: Winterlore I
# Recommended: ['Without Escape' 'Towayami' 'The White Door' 'Panmorphia' 'Veritas']
#
# Game Title: Wishing Sarah
# Recommended: ['Dreaming Sarah' 'Viv and Bob' 'Tiny Dangerous Dungeons' 'Sewer Rave'
#  'Patches Of Adventure']
#
# Game Title: Witch Thief
# Recommended: ['Woodland Chasers' 'WitchWay' 'BAKED:MAGIC' 'Jet Buster' 'Witchball']
#
# Game Title: WitchWay
# Recommended: ['Little Bug (full version)' 'Stick Nightmare'
#  'Adventures of a Radish(Full)' 'Aerannis' 'Escape from Life Inc']
#
# Game Title: Witchball
# Recommended: ['Turn-Based Champion' 'Daemon Detective Racing Zero' 'Super Dunkman'
#  'Served' 'B.O.O.M. - You Win [Early Access]']
#
# Game Title: Without Escape
# Recommended: ['Winterlore I' 'Towayami' 'The White Door' 'Panmorphia' 'The Supper']
#
# Game Title: Wizard Battle
# Recommended: ['The Death of the Corpse Wizard' 'Polymute' 'Blockara' 'Collared'
#  'That Puzzle Game Everyone Knows']
#
# Game Title: Wondee
# Recommended: ['Flash Point: Fire Rescue' 'BulletHell Planes' 'Peck N Run'
#  "Switch 'N' Shoot" 'Timebomb']
#
# Game Title: Wooden Hearts
# Recommended: ['What happened to Survey Team 4?' 'KIDS' 'AIdol' 'Location Withheld'
#  'Where is cat?']
#
# Game Title: Woodland Chasers
# Recommended: ['Witch Thief' 'WitchWay' 'The Witches Tea Party (Light Version)'
#  'Monster Pub Chapter 3' 'Monster Pub Chapter 1']
#
# Game Title: Word After Word
# Recommended: ['Wordsum Blitz' 'Word Forward' 'Nuvoloso' 'Turn-Based Champion'
#  'Last Word']
#
# Game Title: Word Forward
# Recommended: ['Word After Word' 'Wordsum Blitz' 'Sidewords' 'Nuvoloso' 'Last Word']
#
# Game Title: Wordsum Blitz
# Recommended: ['Word After Word' 'Word Forward' 'That Puzzle Game Everyone Knows'
#  'Stoneblade' 'Nuvoloso']
#
# Game Title: Woter-a tale of two water cans - Game jam demo
# Recommended: ['Spring Falls' 'Flowerdrops' 'MULTIPUCK' 'Brassica - A Marry Tale'
#  'Dimension Drive']
#
# Game Title: WretchWorks Arcade Pack
# Recommended: ["Switch 'N' Shoot" 'Ghost Grab 3000' 'Timebomb' 'Space Mayhem'
#  'Astral Defense']
#
# Game Title: Xander the Monster Morpher: Universe Breaker
# Recommended: ['Monster Match' 'Book of Eos' 'Monster Pub Chapter 1'
#  'Monster Pub Chapter 2' 'Monster Pub Chapter 3']
#
# Game Title: Xenogunner
# Recommended: ['Hammer Bomb' 'WILOO' 'Gambol' 'Gutwhale' 'Crystal Story: Awakening']
#
# Game Title: Yi and the Thousand Moons
# Recommended: ['Dominique Pamplemousse in "It\'s All Over Once The Fat Lady Sings!"'
#  'Fugue'
#  'Dominique Pamplemousse and Dominique Pamplemousse in "Combinatorial Explosion!"'
#  'LYNE' 'PizzaBoy']
#
# Game Title: You Died but a Necromancer revived you
# Recommended: ['Skeletris' 'Goopty Goo' 'Bleed 2' 'Crate Punks'
#  'Adventures of a Radish(Full)']
#
# Game Title: Your Future Self
# Recommended: ['Fortune-499' 'Code 7 - Episodes 2 & 3 Available Now' 'The Away Team'
#  'PALACE OF WOE' 'MULTIPUCK']
#
# Game Title: ZEPTON
# Recommended: ['Lazy Galaxy: Rebel Story' 'Galactic Wars' 'Super Ledgehop: Double Laser'
#  'Jet Buster' 'Blast Rush']
#
# Game Title: Zak
# Recommended: ['Perspectrum' 'WILOO' 'Blitz Breaker' 'NiNi' 'Underhero']
#
# Game Title: Zenodyne R
# Recommended: ['Jet Buster' 'Cycle 28' 'Super Ledgehop: Double Laser' 'Cat Ace'
#  'Astral Defense']
#
# Game Title: Zenohell
# Recommended: ['Hyper Sentinel' 'Cat Ace' 'Over Run' 'Those Spacecrafts'
#  "Switch 'N' Shoot"]
#
# Game Title: Zepball Deluxe
# Recommended: ['PuPaiPo Space Deluxe' 'That Puzzle Game Everyone Knows'
#  'Dee Dum (Computer)' 'TAMASHII' 'Sheep Dreams Are Made of This']
#
# Game Title: Zeph
# Recommended: ['Space Madness' 'Star and Light 1.0' 'Solar Collector' 'Inner'
#  'GRAVITY FIGHTERS']
#
# Game Title: Zone of Lacryma
# Recommended: ['Lazy Galaxy: Rebel Story' 'Hyper Sentinel' 'CORPSE REVIVER' 'ZEPTON'
#  'Task Force Kampas']
#
# Game Title: [EN/ESP] The Tail Makes the Fox - Episode 1
# Recommended: ['Blue Rose' 'Belong' 'Slam Fighter II' 'That Which Binds Us'
#  "Dialogue: A Writer's Story"]
#
# Game Title: [HTC Vive] VR Drum Studio
# Recommended: ['Locomancer' 'These Lands' 'Sushi Master VR -  寿司職人VR -' 'Drum Brain'
#  'Cabbibos Play Pack']
#
# Game Title: [HammerA] HammerTime !
# Recommended: ['12 Labors' 'That Which Binds Us' "DON'T WAKE THE NIGHT"
#  'Tales from the Road' 'The Alabaster Donut Farm']
#
# Game Title: [SIBERIA]
# Recommended: ['樺ヶ原脱出 - Escape from Kabagahara'
#  'ADLENGINE - Roleplay / Text Adventure Engine' 'String Tyrant' 'Pyramid'
#  'The Morrison Survival Game']
#
# Game Title: [Speer]
# Recommended: ['Stick Nightmare' 'Portal Dogs'
#  "Me and (My) Cat's Castle -わたしと(わたしの)ねこのしろ-" 'Binaries' 'Pichon!']
#
# Game Title: a completely normal dating simulation that is definitely completely sweet, innocent and normal
# Recommended: ['songs and flowers' 'A Normal Lost Phone' 'Meeting in the Flesh'
#  'Prince of Cats' 'Blue Rose']
#
# Game Title: a new life.
# Recommended: ['Arcade Spirits' 'Make It Last' 'Blind Men' 'Serre' 'Thing-in-Itself']
#
# Game Title: adjacency
# Recommended: ['SOMOS' 'Color Jumper' 'Theorem' 'Cardinal Chains' 'Affinity']
#
# Game Title: as long as we're together: magical girls sweet & pure
# Recommended: ['This World Unknown'
#  'Ecchi Sketch: Draw Cute Girls Every Day! (All Ages Ver)' 'AIdol'
#  'Blue Rose' 'As We Know It']
#
# Game Title: cityglitch
# Recommended: ['Kalling Kingdom' 'Glitch Strike' 'Gun Rounds' 'reYal' 'Turn Chase']
#
# Game Title: down.
# Recommended: ['IMMURE' 'The Space Between' 'Bonbon' 'please' 'Eizoku']
#
# Game Title: east van EP
# Recommended: ['The Night Journey' 'Fugue in Void' 'Walking Tourist'
#  'Guide of the Butterfly' 'D.M.T']
#
# Game Title: falling is not the same thing as dying
# Recommended: ['Tales from the Road' 'MetaWare High School (Demo)' 'NO THING'
#  "as long as we're together: magical girls sweet & pure"
#  'Superhuman Industrial and Immaterial, Incorporated']
#
# Game Title: forma.8
# Recommended: ['The Last Librarian' 'Vision Soft Reset' 'Germination' 'MewnBase'
#  'Aerannis']
#
# Game Title: iZBOT
# Recommended: ['Blitz Breaker' "Switch 'N' Shoot" 'Silver Grapple' 'Stick Nightmare'
#  'Wampus']
#
# Game Title: if not us
# Recommended: ['Tales from the Road' 'ADLENGINE - Roleplay / Text Adventure Engine'
#  'The Away Team' 'Your Future Self'
#  'falling is not the same thing as dying']
#
# Game Title: inSynch
# Recommended: ['Soundodger+' 'Atchafalaya Arcade' 'A Light Long Gone' 'Flux' 'NO THING']
#
# Game Title: kno
# Recommended: ['plant daddy' 'AIdol' 'The Quiet Sleep' 'Meditation 5' 'Affinity']
#
# Game Title: luminous corridor 0
# Recommended: ['Resistance is Fruitile' 'SuperLuminauts' 'Meditation 5' 'Retromancer'
#  'Bleed']
#
# Game Title: monad
# Recommended: ['The Night Journey' 'Atchafalaya Arcade' 'Fugue in Void' 'Concentric'
#  'Astæria']
#
# Game Title: nullpointer
# Recommended: ['Quadrilateral Cowboy' 'INDECT' 'Penance' 'Neon Blight: Final Demo'
#  "WATER'S FINE"]
#
# Game Title: perfect park
# Recommended: ['THE GREY MAN' 'Daemon Detective Racing Zero' 'FutureGrind'
#  'Peace of Mind' 'CARBAGE']
#
# Game Title: plant daddy
# Recommended: ['Potion Commotion:  Heart Edition' 'Mendel' 'Glittermitten Grove'
#  'Quiet as a Stone' 'Village Monsters']
#
# Game Title: please
# Recommended: ['Please Follow' 'IMMURE' 'Grime & Gaslight' 'MORFOSI｜莫法西'
#  'Sanguine Sanctum']
#
# Game Title: probability 0
# Recommended: ['Gumgem' "Lenna's Inception" 'Nano Driller' 'EAT GIRL' 'HexaCycle']
#
# Game Title: reYal
# Recommended: ['OneShot' 'TAMASHII' 'Monster Match' 'cityglitch' 'HATCH']
#
# Game Title: reky
# Recommended: ['HexaCycle' 'IGEO' 'Shn!p' 'No More Kings' 'RYB']
#
# Game Title: ring ring
# Recommended: ["Another Lost Phone: Laura's Story" 'A Normal Lost Phone' 'Terri-Fried'
#  'Ring of Fire Prologue' 'HATCH']
#
# Game Title: songs and flowers
# Recommended: ['Meeting in the Flesh' 'Blue Rose' 'Destiny Fails Us: A New Life'
#  'Starlight Shores' 'Belong']
#
# Game Title: soundStrider
# Recommended: ['A Lullaby of Colors (now available for Oculus Quest too)'
#  'Peak Bleak Blues (and other moods)' 'Fugue in Void' 'Walking Tourist'
#  'CORPSE REVIVER']
#
# Game Title: starseed pilgrim
# Recommended: ['Veritas' 'Winterlore I' 'GNOG' 'The Fall of Lazarus' 'Flowerdrops']
#
# Game Title: stop
# Recommended: ['Qavo' 'Garrison Gauntlet' 'Mobility! Accessible precision platformer'
#  'Theorem' 'Orbis - Throw them all!']
#
# Game Title: this discord has ghosts in it
# Recommended: ['Image of Perfection' 'Speed Dating for Ghosts' 'Ghost Story'
#  'Ghost Grab 3000' 'Spooky Ghosts Dot Com']
#
# Game Title: tumbleblox
# Recommended: ['OneShot' 'Nigel' 'GRAVITY FIGHTERS' 'A Game of Changes' 'Myth Bearer']
#
# Game Title: warm
# Recommended: ['As We Know It' 'Dungeons & Lesbians' 'Highway Blossoms: Remastered'
#  "A NIGHTMARE'S TRIP" 'Waiting for the Loop']
#
# Game Title: whirlibird
# Recommended: ["Switch 'N' Shoot" 'WretchWorks Arcade Pack' 'Skeletris'
#  'Boom Boom Bovine' 'EVADER']
#
# Game Title: who will you save? who will you serve?
# Recommended: ['MORFOSI｜莫法西' 'Haiduc' 'SACRIFICE' 'IMMURE' 'please']
#
# Game Title: you used to be someone
# Recommended: ['Homing' 'down.' 'Walking Tourist' 'Fugue in Void'
#  'Once Upon A Crime in the West']
#
# Game Title: 樺ヶ原脱出 - Escape from Kabagahara
# Recommended: ['[SIBERIA]' 'Grime & Gaslight' 'Inner' 'String Tyrant' 'IMMURE']
#
# Game Title: 盆栽 カレンダー (BONSAI CALENDAR)
# Recommended: ['Speed Dating for Ghosts'
#  "Don't Take It Personally, I Just Don't Like You: The Camping Trip"
#  'Meeting in the Flesh' 'songs and flowers' 'Subterrarium']

# %%
#saving the recommendations for each game into a txt file
with open("itch.io-Bundle-Recommendations.txt", "w", encoding="utf-8") as outfile:
    for game in games_list:
        results = recommender(game, games=games_titles, similarity_score=similarities_df)
        results_list = results.tolist()
        results_list.insert(0,game)
        outfile.write(str(results_list))
        outfile.write("\n")
